# %%
# Libraries and Dataset

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
# %matplotlib inline
dataset = pd.read_csv('Azerbeijan GP.csv')
dataset.head(20)
# Out:
#     position            driver  driverId     constructor  constructorId  laps  \
# 0        1.0    Max Verstappen        50        Red Bull            9.0    51
# 1        2.0      Sergio Pérez       815        Red Bull            9.0    51
# 2        3.0    George Russell       847        Mercedes           13.1    51
# 3        4.0    Lewis Hamilton         1        Mercedes           13.1    51
# 4        5.0      Pierre Gasly       842      AlphaTauri           21.3    51
# 5        6.0  Sebastian Vettel        20    Aston Martin           11.7    51
# 6        7.0   Fernando Alonso         4  Alpine F1 Team           21.4    51
# 7        8.0  Daniel Ricciardo       817         McLaren            1.0    51
# 8        9.0      Lando Norris       846         McLaren            1.0    51
# 9       10.0      Esteban Ocon       839  Alpine F1 Team           21.4    51
# 10      11.0   Valtteri Bottas        77      Alfa Romeo           51.0    50
# ...

# %%
# X = Drivers ID, y = Final Position, Z = Constructors ID, H = Grid

X = dataset.iloc[:-4,2:-6].values
y = dataset.iloc[:-4,:-8].values
Z = dataset.iloc[:-4,4:-4].values
H = dataset.iloc[:-4,8:].values

# %%
# Machine Learning Regression Grid VS Final Position

from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(H, y)
# Out:
# LinearRegression()

# %%
# Azerbeijan GP Driver Position

plt.figure(figsize=(15,10))
plt.grid(color='green', linestyle='--', linewidth='0.5')
plt.scatter(X, y, color = 'blue')
plt.title('Azerbeijan GP Driver Position')
plt.xlabel('Driver ID')
plt.ylabel('Position')
# Out:
# Text(0, 0.5, 'Position')

# %%
# Azerbeijan GP Constructor Position

plt.figure(figsize=(15,10))
plt.grid(color='green', linestyle='--', linewidth='0.5')
plt.scatter(Z, y, color = 'blue')
plt.title('Azerbeijan GP Constructor Position')
plt.xlabel('Constructor ID')
plt.ylabel('Position')
# Out:
# Text(0, 0.5, 'Position')

# %%
# Azerbeijan GP Driver Points

f, ax = plt.subplots(figsize=(15, 10))
sns.barplot(x='points', y='driver', data=dataset)
plt.title('Azerbeijan GP Driver Points')
plt.xlabel('GP Points')
plt.ylabel('Drivers')
# Out:
# Text(0, 0.5, 'Drivers')

# %%
# Azerbeijan GP Constructor Points

f, ax = plt.subplots(figsize=(15, 10))
sns.barplot(x='points', y='constructor', data=dataset)
plt.title('Azerbeijan GP Constructor Points')
plt.xlabel('GP Points')
plt.ylabel('Constructors')
# Out:
# Text(0, 0.5, 'Constructors')

# %%
# Azerbeijan GP Grid VS Final Position

plt.figure(figsize=(15, 10))
plt.grid(color='green', linestyle='--', linewidth=0.5)
plt.scatter(H, y, color = 'red')
plt.plot(H, regressor.predict(H), color = 'blue')
plt.title('Grid VS Finish')
plt.xlabel('Start Position')
plt.ylabel('Finish')
# Out:
# Text(0, 0.5, 'Finish')
