# %%
# Libraries and Dataset

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
# %matplotlib inline
dataset = pd.read_csv('Monaco GP.csv')
dataset.head(20)
# Out:
#     position            driver  driverId     constructor  constructorId  laps  \
# 0        1.0      Sergio Pérez       815        Red Bull            9.0    64
# 1        2.0      Carlos Sainz       832         Ferrari            6.0    64
# 2        3.0    Max Verstappen        50        Red Bull            9.0    64
# 3        4.0   Charles Leclerc       844         Ferrari            6.0    64
# 4        5.0    George Russell       847        Mercedes           13.1    64
# 5        6.0      Lando Norris       846         McLaren            1.0    64
# 6        7.0   Fernando Alonso         4  Alpine F1 Team           21.4    64
# 7        8.0    Lewis Hamilton         1        Mercedes            1.0    64
# 8        9.0   Valtteri Bottas        77      Alfa Romeo           51.0    64
# 9       10.0  Sebastian Vettel        20    Aston Martin           11.7    64
# 10      11.0      Pierre Gasly       842      AlphaTauri           21.3    64
# 11      12.0      Esteban Ocon       839  Alpine F1 Team           21.4    64
# 12      13.0  Daniel Ricciardo       817         McLaren            1.0    64
# 13      14.0      Lance Stroll       840    Aston Martin           11.7    64
# 14      15.0   Nicholas Latifi         5        Williams            3.0    63
# 15      16.0       Guanyu Zhou        24      Alfa Romeo           51.0    63
# 16      17.0      Yuki Tsunoda       852      AlphaTauri           21.3    63
# 17       NaN   Alexander Albon        23        Williams            3.0    48
# 18       NaN   Mick Schumacher        47    Haas F1 Team           21.0    24
# 19       NaN   Kevin Magnussen        76    Haas F1 Team           21.0    19
#
#               time  points  grid
# 0      1:56:30.265      25     3
# 1            1.154      18     2
# 2            1.491      15     4
# 3            2.922      12     1
# 4           11.968      10     6
# 5           12.231       9     5
# 6           46.358       6     7
# 7           50.388       4     8
# 8           52.525       2    12
# 9           53.536       1     9
# 10          54.289       0    17
# 11          55.644       0    10
# 12          57.635       0    14
# 13       +1:00.802       0    18
# 14          +1 Lap       0    19
# 15          +1 Lap       0    20
# 16          +1 Lap       0    11
# 17      Mechanical       0    16
# 18        Accident       0    15
# 19  Water pressure       0    13

# %%
# X = Drivers ID, y = Final Position, Z = Constructors ID, H = Grid

X = dataset.iloc[:-3,2:-6].values
y = dataset.iloc[:-3,:-8].values 
Z = dataset.iloc[:-3,4:-4].values
H = dataset.iloc[:-3,8:].values

# %%
# Machine Learning Regression Grid VS Final Position 

from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(H, y)
# Out:
# LinearRegression()

# %%
# Monaco GP Driver Position

plt.figure(figsize=(15,10))
plt.grid(color='green', linestyle='--', linewidth='0.5')
plt.scatter(X, y, color = 'blue')
plt.title('Monaco GP Driver Position')
plt.xlabel('Driver ID')
plt.ylabel('Position')
# Out:
# Text(0, 0.5, 'Position')

# %%
# Monaco GP Constructor Position

plt.figure(figsize=(15,10))
plt.grid(color='green', linestyle='--', linewidth='0.5')
plt.scatter(Z, y, color = 'blue')
plt.title('Monaco GP Constructor Position')
plt.xlabel('Constructor ID')
plt.ylabel('Position')
# Out:
# Text(0, 0.5, 'Position')

# %%
# Monaco GP Driver Points

f, ax = plt.subplots(figsize=(15, 10))
sns.barplot(x='points', y='driver', data=dataset)
plt.title('Monaco GP Driver Points')
plt.xlabel('GP Points')
plt.ylabel('Drivers')
# Out:
# Text(0, 0.5, 'Drivers')

# %%
# Monaco GP Constructor Points

f, ax = plt.subplots(figsize=(15, 10))
sns.barplot(x='points', y='constructor', data=dataset)
plt.title('Monaco GP Constructor Points')
plt.xlabel('GP Points')
plt.ylabel('Constructors')
# Out:
# Text(0, 0.5, 'Constructors')

# %%
# Monaco GP Grid VS Final Position

plt.figure(figsize=(15, 10))
plt.grid(color='green', linestyle='--', linewidth=0.5)
plt.scatter(H, y, color = 'red')
plt.plot(H, regressor.predict(H), color = 'blue')
plt.title('Grid VS Finish')
plt.xlabel('Start Position')
plt.ylabel('Finish')
# Out:
# Text(0, 0.5, 'Finish')
