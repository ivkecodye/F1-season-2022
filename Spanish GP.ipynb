# %%
# Libraries and Dataset

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
# %matplotlib inline
dataset = pd.read_csv('Spanish GP.csv')
dataset.head(20)
# Out:
#     position            driver  driverId     constructor  constructorId  laps  \
# 0        1.0    Max Verstappen        50        Red Bull            9.0    66
# 1        2.0      Sergio Pérez       815        Red Bull            9.0    66
# 2        3.0    George Russell       847        Mercedes           13.1    66
# 3        4.0      Carlos Sainz       832         Ferrari            6.0    66
# 4        5.0    Lewis Hamilton         1        Mercedes           13.1    66
# 5        6.0   Valtteri Bottas        77      Alfa Romeo           51.0    66
# 6        7.0      Esteban Ocon       839  Alpine F1 Team           21.4    66
# 7        8.0      Lando Norris       846         McLaren            1.0    66
# 8        9.0   Fernando Alonso         4  Alpine F1 Team           21.4    65
# 9       10.0      Yuki Tsunoda       852      AlphaTauri           21.3    65
# 10      11.0  Sebastian Vettel        20    Aston Martin           11.7    65
# 11      12.0  Daniel Ricciardo       817         McLaren            1.0    65
# 12      13.0      Pierre Gasly       842      AlphaTauri           21.3    65
# 13      14.0   Mick Schumacher        47    Haas F1 Team           21.0    65
# 14      15.0      Lance Stroll       840    Aston Martin           11.7    65
# 15      16.0   Nicholas Latifi         5        Williams            3.0    64
# 16      17.0   Kevin Magnussen        76    Haas F1 Team           21.0    64
# 17      18.0   Alexander Albon        23        Williams            3.0    64
# 18       NaN       Guanyu Zhou        24      Alfa Romeo           51.0    28
# 19       NaN   Charles Leclerc       844         Ferrari            6.0    27
#
#            time  points  grid
# 0   1:37:20.475      25     2
# 1        13.072      19     5
# 2        32.927      15     4
# 3        45.208      12     3
# 4        54.534      10     6
# 5        59.976       8     7
# 6     +1:15.397       6    12
# 7     +1:23.235       4    11
# 8        +1 Lap       2    17
# 9        +1 Lap       1    13
# 10       +1 Lap       0    16
# 11       +1 Lap       0     9
# 12       +1 Lap       0    14
# 13       +1 Lap       0    10
# 14       +1 Lap       0    18
# 15      +2 Laps       0    20
# 16      +2 Laps       0     8
# 17      +2 Laps       0    19
# 18   Power loss       0    15
# 19        Turbo       0     1

# %%
# X = Drivers ID, y = Final Position, Z = Constructors ID, H = Grid

X = dataset.iloc[:-2,2:-6].values
y = dataset.iloc[:-2,:-8].values
Z = dataset.iloc[:-2,4:-4].values
H = dataset.iloc[:-2,8:].values

# %%
# Machine Learning Regression Grid VS Final Position

from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(H, y)
# Out:
# LinearRegression()

# %%
# Spanish GP Driver Position

plt.figure(figsize=(15,10))
plt.grid(color='green', linestyle='--', linewidth=0.5)
plt.scatter(X, y, color = 'blue')
plt.title('Spanish GP Driver Position')
plt.xlabel('Driver ID')
plt.ylabel('Position')
# Out:
# Text(0, 0.5, 'Position')

# %%
# Spanish GP Constructor Position

plt.figure(figsize=(15,10))
plt.grid(color='green', linestyle='--', linewidth=0.5)
plt.scatter(Z, y, color = 'blue')
plt.title('Spanish GP Constructor Position')
plt.xlabel('Constructor ID')
plt.ylabel('Position')
# Out:
# Text(0, 0.5, 'Position')

# %%
# Spanish GP Driver Points

f, ax = plt.subplots(figsize=(15,10))
sns.barplot(x='points', y='driver', data=dataset)
plt.title('Spanish GP Driver Points')
plt.xlabel('GP Points')
plt.ylabel('Drivers')
# Out:
# Text(0, 0.5, 'Drivers')

# %%
# Spanish GP Constructor Points

f, ax = plt.subplots(figsize=(15,10))
sns.barplot(x='points', y='constructor', data=dataset)
plt.title('Spanish GP Constructor Points')
plt.xlabel('GP Points')
plt.ylabel('Constructors')
# Out:
# Text(0, 0.5, 'Constructors')

# %%
# Spanish GP Grid VS Final Position

plt.figure(figsize=(15,10))
plt.grid(color='green', linestyle='--', linewidth=0.5)
plt.scatter(H, y, color = 'red')
plt.plot(H, regressor.predict(H), color = 'blue')
plt.title('Grid VS Finish')
plt.xlabel('Start Position')
plt.ylabel('Finish')
# Out:
# Text(0, 0.5, 'Finish')
