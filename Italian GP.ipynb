# %%
# Libraries and Dataset

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
# %matplotlib inline
dataset = pd.read_csv('Italian GP.csv')
dataset.head(20)
# Out:
#     position            driver  driver id     constructor  constructor id  \
# 0        1.0    Max Verstappen         50        Red Bull             9.0
# 1        2.0   Charles Leclerc        844         Ferrari             6.0
# 2        3.0    George Russell        847        Mercedes            13.1
# 3        4.0      Carlos Sainz        832         Ferrari             6.0
# 4        5.0    Lewis Hamilton          1        Mercedes            13.1
# 5        6.0      Sergio Pérez        815        Red Bull             9.0
# 6        7.0      Lando Norris        846         McLaren             1.0
# 7        8.0      Pierre Gasly        842      AlphaTauri            21.3
# 8        9.0     Nyck de Vries        856        Williams             3.0
# 9       10.0       Guanyu Zhou         24      Alfa Romeo            51.0
# 10      11.0      Esteban Ocon        839  Alpine F1 Team            21.4
# 11      12.0   Mick Schumacher         47    Haas F1 Team            21.0
# 12      13.0   Valtteri Bottas         77      Alfa Romeo            51.0
# 13      14.0      Yuki Tsunoda        852      AlphaTauri            21.3
# 14      15.0   Nicholas Latifi          5        Williams             3.0
# 15      16.0   Kevin Magnussen         76    Haas F1 Team            21.0
# 16       NaN  Daniel Ricciardo        817         McLaren             1.0
# 17       NaN      Lance Stroll        840    Aston Martin            11.7
# 18       NaN   Fernando Alonso          4  Alpine F1 Team            21.4
# 19       NaN  Sebastian Vettel         20    Aston Martin            11.7
#
#     laps            time  points  grid
# 0     53     1:20:27.511    25.0     2
# 1     53           2.446    18.0     1
# 2     53           3.405    15.0     6
# 3     53           5.061    12.0     3
# 4     53           5.380    10.0     5
# 5     53           6.091     9.0     4
# 6     53           6.207     6.0     7
# 7     53           6.396     4.0     9
# 8     53           7.122     2.0    13
# 9     53           7.910     1.0    14
# 10    53           8.323     0.0    11
# 11    53           8.549     0.0    20
# 12    52          +1 Lap     0.0    12
# 13    52          +1 Lap     0.0    15
# 14    52          +1 Lap     0.0    16
# 15    52          +1 Lap     0.0    19
# 16    45        Oil leak     0.0     8
# 17    39          Engine     0.0    18
# 18    31  Water pressure     0.0    10
# 19    10          Engine     NaN    17

# %%
# X = Drivers ID, y = Final Position, Z = Constructors ID, H = Grid

X = dataset.iloc[:-4,2:-6].values
y = dataset.iloc[:-4,:-8].values 
Z = dataset.iloc[:-4,4:-4].values
H = dataset.iloc[:-4,8:].values

# %%
# Machine Learning Regression Grid VS Final Position 

from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(H, y)
# Out:
# LinearRegression()

# %%
# Italian GP Driver Position

plt.figure(figsize=(15,10))
plt.grid(color='green', linestyle='--', linewidth='0.5')
plt.scatter(X, y, color = 'blue')
plt.title('Italian GP Driver Position')
plt.xlabel('Driver ID')
plt.ylabel('Position')
# Out:
# Text(0, 0.5, 'Position')

# %%
# Italian GP Constructor Position

plt.figure(figsize=(15,10))
plt.grid(color='green', linestyle='--', linewidth='0.5')
plt.scatter(Z, y, color = 'blue')
plt.title('Italian GP Constructor Position')
plt.xlabel('Constructor ID')
plt.ylabel('Position')
# Out:
# Text(0, 0.5, 'Position')

# %%
# Italian GP Driver Points

f, ax = plt.subplots(figsize=(15, 10))
sns.barplot(x='points', y='driver', data=dataset)
plt.title('Italian GP Driver Points')
plt.xlabel('GP Points')
plt.ylabel('Drivers')
# Out:
# Text(0, 0.5, 'Drivers')

# %%
# Italian GP Constructor Points

f, ax = plt.subplots(figsize=(15, 10))
sns.barplot(x='points', y='constructor', data=dataset)
plt.title('Italian GP Constructor Points')
plt.xlabel('GP Points')
plt.ylabel('Constructors')
# Out:
# Text(0, 0.5, 'Constructors')

# %%
# Italian GP Grid VS Final Position

plt.figure(figsize=(15, 10))
plt.grid(color='green', linestyle='--', linewidth=0.5)
plt.scatter(H, y, color = 'red')
plt.plot(H, regressor.predict(H), color = 'blue')
plt.title('Grid VS Finish')
plt.xlabel('Start Position')
plt.ylabel('Finish')
# Out:
# Text(0, 0.5, 'Finish')
