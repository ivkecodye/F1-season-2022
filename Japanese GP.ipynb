# %%
# Libraries and Dataset

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
# %matplotlib inline
dataset = pd.read_csv('Japanese GP.csv')
dataset.head(20)
# Out:
#     position            driver  driver id     constructor  constructor id  \
# 0        1.0    Max Verstappen         50        Red Bull             9.0
# 1        2.0      Sergio Pérez        815        Red Bull             9.0
# 2        3.0   Charles Leclerc        844         Ferrari             6.0
# 3        4.0      Esteban Ocon        839  Alpine F1 Team            21.4
# 4        5.0    Lewis Hamilton          1        Mercedes            13.1
# 5        6.0  Sebastian Vettel         20    Aston Martin            11.7
# 6        7.0   Fernando Alonso          4  Alpine F1 Team            21.4
# 7        8.0    George Russell        847        Mercedes            13.1
# 8        9.0   Nicholas Latifi          5        Williams             3.0
# 9       10.0      Lando Norris        846         McLaren             1.0
# 10      11.0  Daniel Ricciardo        817         McLaren             1.0
# 11      12.0      Lance Stroll        840    Aston Martin            11.7
# 12      13.0      Yuki Tsunoda        852      AlphaTauri            21.3
# 13      14.0   Kevin Magnussen         76    Haas F1 Team            21.0
# 14      15.0   Valtteri Bottas         77      Alfa Romeo            51.0
# 15      16.0       Guanyu Zhou         24      Alfa Romeo            51.0
# 16      17.0   Mick Schumacher         47    Haas F1 Team            21.0
# 17      18.0      Pierre Gasly        842      AlphaTauri            21.3
# 18       NaN   Alexander Albon         23        Williams             3.0
# 19       NaN      Carlos Sainz        832         Ferrari             6.0
#
#     laps         time  points  grid
# 0     28  3:01:44.004      25     1
# 1     28       27.066      18     4
# 2     28       31.763      15     2
# 3     28       39.685      12     5
# 4     28       40.326      10     6
# 5     28       46.358       8     9
# 6     28       46.369       6     7
# 7     28       47.661       4     8
# 8     28    +1:10.143       2    20
# 9     28    +1:10.782       1    10
# 10    28    +1:12.877       0    11
# 11    28    +1:13.904       0    19
# 12    28    +1:15.599       0    13
# 13    28    +1:26.016       0    18
# 14    28    +1:26.496       0    12
# 15    28    +1:27.043       0    14
# 16    28    +1:32.523       0    15
# 17    28    +1:48.091       0    17
# 18     0   Hydraulics       0    16
# 19     0     Accident       0     3

# %%
# X = Drivers ID, y = Final Position, Z = Constructors ID, H = Grid

X = dataset.iloc[:-2,2:-6].values
y = dataset.iloc[:-2,:-8].values 
Z = dataset.iloc[:-2,4:-4].values
H = dataset.iloc[:-2,8:].values

# %%
# Machine Learning Regression Grid VS Final Position 

from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(H, y)
# Out:
# LinearRegression()

# %%
# Japanese GP Driver Position

plt.figure(figsize=(15,10))
plt.grid(color='green', linestyle='--', linewidth='0.5')
plt.scatter(X, y, color = 'blue')
plt.title('Japanese GP Driver Position')
plt.xlabel('Driver ID')
plt.ylabel('Position')
# Out:
# Text(0, 0.5, 'Position')

# %%
# Japanese GP Constructor Position

plt.figure(figsize=(15,10))
plt.grid(color='green', linestyle='--', linewidth='0.5')
plt.scatter(Z, y, color = 'blue')
plt.title('Japanese GP Constructor Position')
plt.xlabel('Constructor ID')
plt.ylabel('Position')
# Out:
# Text(0, 0.5, 'Position')

# %%
# Japanese GP Driver Points

f, ax = plt.subplots(figsize=(15, 10))
sns.barplot(x='points', y='driver', data=dataset)
plt.title('Japanese GP Driver Points')
plt.xlabel('GP Points')
plt.ylabel('Drivers')
# Out:
# Text(0, 0.5, 'Drivers')

# %%
# Japanese GP Constructor Points

f, ax = plt.subplots(figsize=(15, 10))
sns.barplot(x='points', y='constructor', data=dataset)
plt.title('Japanese GP Constructor Points')
plt.xlabel('GP Points')
plt.ylabel('Constructors')
# Out:
# Text(0, 0.5, 'Constructors')

# %%
# Japanese GP Grid VS Final Position

plt.figure(figsize=(15, 10))
plt.grid(color='green', linestyle='--', linewidth=0.5)
plt.scatter(H, y, color = 'red')
plt.plot(H, regressor.predict(H), color = 'blue')
plt.title('Grid VS Finish')
plt.xlabel('Start Position')
plt.ylabel('Finish')
# Out:
# Text(0, 0.5, 'Finish')
