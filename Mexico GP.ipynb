# %%
# Libraries and Dataset

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
# %matplotlib inline
dataset = pd.read_csv('Mexico GP.csv')
dataset.head(20)
# Out:
#     position            driver  driver id     constructor  constructor id  \
# 0        1.0    Max Verstappen         50        Red Bull             9.0
# 1        2.0    Lewis Hamilton          1        Mercedes            13.1
# 2        3.0      Sergio Pérez        815        Red Bull             9.0
# 3        4.0    George Russell        847        Mercedes            13.1
# 4        5.0      Carlos Sainz        832         Ferrari             6.0
# 5        6.0   Charles Leclerc        844         Ferrari             6.0
# 6        7.0  Daniel Ricciardo        817         McLaren             1.0
# 7        8.0      Esteban Ocon        839  Alpine F1 Team            21.4
# 8        9.0      Lando Norris        846         McLaren             1.0
# 9       10.0   Valtteri Bottas         77      Alfa Romeo            51.0
# 10      11.0      Pierre Gasly        842      AlphaTauri            21.3
# 11      12.0   Alexander Albon         23        Williams             3.0
# 12      13.0       Guanyu Zhou         24      Alfa Romeo            51.0
# 13      14.0  Sebastian Vettel         20    Aston Martin            11.7
# 14      15.0      Lance Stroll        840    Aston Martin            11.7
# 15      16.0   Mick Schumacher         47    Haas F1 Team            21.0
# 16      17.0   Kevin Magnussen         76    Haas F1 Team            21.0
# 17      18.0   Nicholas Latifi          5        Williams             3.0
# 18      19.0   Fernando Alonso          4  Alpine F1 Team            21.4
# 19       NaN      Yuki Tsunoda        852      AlphaTauri            21.3
#
#     laps              time  points  grid
# 0     71       1:38:36.729      25     1
# 1     71            15.186      18     3
# 2     71            18.097      15     4
# 3     71            49.431      13     2
# 4     71            58.123      10     5
# 5     71         +1:08.774       8     7
# 6     70            +1 Lap       6    11
# 7     70            +1 Lap       4    10
# 8     70            +1 Lap       2     8
# 9     70            +1 Lap       1     6
# 10    70            +1 Lap       0    14
# 11    70            +1 Lap       0    19
# 12    70            +1 Lap       0    12
# 13    70            +1 Lap       0    17
# 14    70            +1 Lap       0    18
# 15    70            +1 Lap       0    16
# 16    70            +1 Lap       0    15
# 17    69           +2 Laps       0    20
# 18    63            Engine       0     9
# 19    50  Collision damage       0    13

# %%
# X = Drivers ID, y = Final Position, Z = Constructors ID, H = Grid

X = dataset.iloc[:-1,2:-6].values
y = dataset.iloc[:-1,:-8].values 
Z = dataset.iloc[:-1,4:-4].values
H = dataset.iloc[:-1,8:].values

# %%
# Machine Learning Regression Grid VS Final Position 

from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(H, y)
# Out:
# LinearRegression()

# %%
# Mexico GP Driver Position

plt.figure(figsize=(15,10))
plt.grid(color='green', linestyle='--', linewidth='0.5')
plt.scatter(X, y, color = 'blue')
plt.title('Mexico GP Driver Position')
plt.xlabel('Driver ID')
plt.ylabel('Position')
# Out:
# Text(0, 0.5, 'Position')

# %%
# Mexico GP Constructor Position

plt.figure(figsize=(15,10))
plt.grid(color='green', linestyle='--', linewidth='0.5')
plt.scatter(Z, y, color = 'blue')
plt.title('Mexico GP Constructor Position')
plt.xlabel('Constructor ID')
plt.ylabel('Position')
# Out:
# Text(0, 0.5, 'Position')

# %%
# Mexico GP Driver Points

f, ax = plt.subplots(figsize=(15, 10))
sns.barplot(x='points', y='driver', data=dataset)
plt.title('Mexico GP Driver Points')
plt.xlabel('GP Points')
plt.ylabel('Drivers')
# Out:
# Text(0, 0.5, 'Drivers')

# %%
# Mexico GP Constructor Points

f, ax = plt.subplots(figsize=(15, 10))
sns.barplot(x='points', y='constructor', data=dataset)
plt.title('Mexico GP Constructor Points')
plt.xlabel('GP Points')
plt.ylabel('Constructors')
# Out:
# Text(0, 0.5, 'Constructors')

# %%
# Mexico GP Grid VS Final Position

plt.figure(figsize=(15, 10))
plt.grid(color='green', linestyle='--', linewidth=0.5)
plt.scatter(H, y, color = 'red')
plt.plot(H, regressor.predict(H), color = 'blue')
plt.title('Grid VS Finish')
plt.xlabel('Start Position')
plt.ylabel('Finish')
# Out:
# Text(0, 0.5, 'Finish')
