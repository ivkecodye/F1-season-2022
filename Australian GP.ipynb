# %%
# Libraries and Dataset

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
# %matplotlib inline
dataset = pd.read_csv('Australian GP.csv')
dataset.head(20)
# Out:
#     position            driver  driverId     constructor  constructorId  laps  \
# 0        1.0   Charles Leclerc     844.0         Ferrari            6.0    58
# 1        2.0      Sergio Pérez     815.0        Red Bull            9.0    58
# 2        3.0    George Russell     847.0        Mercedes           13.1    58
# 3        4.0    Lewis Hamilton       1.0        Mercedes           13.1    58
# 4        5.0      Lando Norris     846.0         McLaren            1.0    58
# 5        6.0  Daniel Ricciardo     817.0         McLaren            1.0    58
# 6        7.0      Esteban Ocon     839.0  Alpine F1 Team           21.4    58
# 7        8.0   Valtteri Bottas      77.0      Alfa Romeo           51.0    58
# 8        9.0      Pierre Gasly     842.0      AlphaTauri           21.3    58
# 9       10.0   Alexander Albon      23.0        Williams            3.0    58
# 10      11.0       Guanyu Zhou      24.0      Alfa Romeo           51.0    58
# 11      12.0      Lance Stroll     840.0    Aston Martin           11.7    58
# 12      13.0   Mick Schumacher      47.0    Haas F1 Team           21.0    57
# 13      14.0   Kevin Magnussen      76.0    Haas F1 Team           21.0    57
# 14      15.0      Yuki Tsunoda     852.0      AlphaTauri           21.3    57
# 15      16.0   Nicholas Latifi       5.0        Williams            3.0    57
# 16      17.0   Fernando Alonso       4.0  Alpine F1 Team           21.4    57
# 17       NaN    Max Verstappen      50.0        Red Bull            9.0    38
# 18       NaN  Sebastian Vettel       NaN    Aston Martin           11.7    22
# 19       NaN      Carlos Sainz     832.0         Ferrari            6.0     1
#
#            time  points  Grid
# 0   1:27:46.548      26     1
# 1        20.524      18     3
# 2        25.593      15     6
# 3        28.543      12     5
# 4        53.303      10     4
# 5        53.737       8     7
# 6     +1:01.683       6     8
# 7     +1:08.439       4    12
# 8     +1:16.221       2    11
# 9     +1:19.382       1    16
# 10    +1:21.695       0    14
# 11    +1:28.598       0    20
# 12       +1 Lap       0    15
# 13       +1 Lap       0    17
# 14       +1 Lap       0    13
# 15       +1 Lap       0    19
# 16       +1 Lap       0    10
# 17    Fuel leak       0     2
# 18     Accident       0    18
# 19     Spun off       0     9

# %%
# X = Drivers ID, y = Final Position, Z = Constructors ID, H = Grid

X = dataset.iloc[:-3,2:-6].values
y = dataset.iloc[:-3,:-8].values
Z = dataset.iloc[:-3,4:-4].values
H = dataset.iloc[:-3,8:].values

# %%
# Machine Learning Regression Grid VS Final Position

from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(H, y)
# Out:
# LinearRegression()

# %%
# Australian GP Driver Position

plt.figure(figsize=(15,10))
plt.grid(color='green', linestyle='--', linewidth=0.5)
plt.scatter(X, y, color='blue')
plt.title('Australian GP Driver Positions')
plt.xlabel('Driver ID')
plt.ylabel('Position')
# Out:
# Text(0, 0.5, 'Position')

# %%
# Australian GP Constructor Position

plt.figure(figsize=(15,10))
plt.grid(color='green', linestyle='--', linewidth=0.5)
plt.scatter(Z, y, color='blue')
plt.title('Australian GP Constructor Positions')
plt.xlabel('Constructor ID')
plt.ylabel('Position')
# Out:
# Text(0, 0.5, 'Position')

# %%
# Australian GP Driver Points

f, ax = plt.subplots(figsize=(15,10))
sns.barplot(x='points', y='driver', data=dataset)
plt.title('Australian GP Driver Points')
plt.xlabel('GP Points')
plt.ylabel('Drivers')
# Out:
# Text(0, 0.5, 'Drivers')

# %%
# Australian GP Constructor Points

f, ax = plt.subplots(figsize=(15,10))
sns.barplot(x='points', y='constructor', data=dataset)
plt.title('Australian GP Constructor Points')
plt.xlabel('GP Points')
plt.ylabel('Constructor')
# Out:
# Text(0, 0.5, 'Constructor')

# %%
# Australian GP Grid VS Final Position

plt.figure(figsize=(15,10))
plt.grid(color='green', linestyle='--', linewidth=0.5)
plt.scatter(H, y, color='red')
plt.plot(H, regressor.predict(H), color='blue')
plt.title('Grid VS Finish')
plt.xlabel('Start Position')
plt.ylabel('Finish')
# Out:
# Text(0, 0.5, 'Finish')
