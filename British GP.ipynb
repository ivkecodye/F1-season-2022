# %%
# Libraries and Dataset

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
# %matplotlib inline
dataset = pd.read_csv('British GP.csv')
dataset.head(20)
# Out:
#     position             driver  driver id     constructor  constructor id  \
# 0         1.0      Carlos Sainz        832         Ferrari             6.0
# 1         2.0      Sergio Pérez        815        Red Bull             9.0
# 2         3.0    Lewis Hamilton          1        Mercedes            13.1
# 3         4.0   Charles Leclerc        844         Ferrari             6.0
# 4         5.0   Fernando Alonso          4  Alpine F1 Team            21.4
# 5         6.0      Lando Norris        846         McLaren             1.0
# 6         7.0    Max Verstappen         50        Red Bull             9.0
# 7         8.0   Mick Schumacher         47    Haas F1 Team            21.0
# 8         9.0  Sebastian Vettel         20    Aston Martin            11.7
# 9        10.0   Kevin Magnussen         76    Haas F1 Team            21.0
# 10       11.0      Lance Stroll        840    Aston Martin            11.7
# 11       12.0   Nicholas Latifi          5        Williams             3.0
# 12       13.0  Daniel Ricciardo        817         McLaren             1.0
# 13       14.0      Yuki Tsunoda        852      AlphaTauri            21.3
# 14        NaN      Esteban Ocon        839  Alpine F1 Team            21.4
# 15        NaN      Pierre Gasly        842      AlphaTauri            21.3
# 16        NaN   Valtteri Bottas         77      Alfa Romeo            51.0
# 17        NaN   Alexander Albon         23        Williams             3.0
# 18        NaN       Guanyu Zhou         24      Alfa Romeo            51.0
# 19        NaN    George Russell        847        Mercedes            13.1
#
#     laps              time  points  grid
# 0     52       2:17:50.311      25     1
# 1     52             3.779      18     4
# 2     52             6.225      16     5
# 3     52             8.546      12     3
# 4     52             9.571      10     7
# 5     52            11.943       8     6
# 6     52            18.777       6     2
# 7     52            18.995       4    19
# 8     52            22.356       2    18
# 9     52            24.590       1    17
# 10    52            26.147       0    20
# 11    52            32.511       0    10
# 12    52            32.817       0    14
# 13    52            40.910       0    13
# 14    37         Fuel pump       0    15
# 15    26  Collision damage       0    11
# 16    20           Gearbox       0    12
# 17     0         Collision       0    16
# 18     0         Collision       0     9
# 19     0         Collision       0     8

# %%
# X = Drivers ID, y = Final Position, Z = Constructors ID, H = Grid

X = dataset.iloc[:-6,2:-6].values
y = dataset.iloc[:-6,:-8].values 
Z = dataset.iloc[:-6,4:-4].values
H = dataset.iloc[:-6,8:].values

# %%
# Machine Learning Regression Grid VS Final Position 

from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(H, y)
# Out:
# LinearRegression()

# %%
# British GP Driver Position

plt.figure(figsize=(15,10))
plt.grid(color='green', linestyle='--', linewidth='0.5')
plt.scatter(X, y, color = 'blue')
plt.title('British GP Driver Position')
plt.xlabel('Driver ID')
plt.ylabel('Position')
# Out:
# Text(0, 0.5, 'Position')

# %%
# British GP Constructor Position

plt.figure(figsize=(15,10))
plt.grid(color='green', linestyle='--', linewidth='0.5')
plt.scatter(Z, y, color = 'blue')
plt.title('British GP Constructor Position')
plt.xlabel('Constructor ID')
plt.ylabel('Position')
# Out:
# Text(0, 0.5, 'Position')

# %%
# British GP Driver Points

f, ax = plt.subplots(figsize=(15, 10))
sns.barplot(x='points', y='driver', data=dataset)
plt.title('British GP Driver Points')
plt.xlabel('GP Points')
plt.ylabel('Drivers')
# Out:
# Text(0, 0.5, 'Drivers')

# %%
# British GP Constructor Points

f, ax = plt.subplots(figsize=(15, 10))
sns.barplot(x='points', y='constructor', data=dataset)
plt.title('British GP Constructor Points')
plt.xlabel('GP Points')
plt.ylabel('Constructors')
# Out:
# Text(0, 0.5, 'Constructors')

# %%
# British GP Grid VS Final Position

plt.figure(figsize=(15, 10))
plt.grid(color='green', linestyle='--', linewidth=0.5)
plt.scatter(H, y, color = 'red')
plt.plot(H, regressor.predict(H), color = 'blue')
plt.title('Grid VS Finish')
plt.xlabel('Start Position')
plt.ylabel('Finish')
# Out:
# Text(0, 0.5, 'Finish')
