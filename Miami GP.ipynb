# %%
# Libraries and Dataset

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
# %matplotlib inline
dataset = pd.read_csv('Miami GP.csv')
dataset.head(20)
# Out:
#     position            driver  driverId     constructor  constructorId  laps  \
# 0        1.0    Max Verstappen        50        Red Bull            9.0    57
# 1        2.0   Charles Leclerc       844         Ferrari            6.0    57
# 2        3.0      Carlos Sainz       832         Ferrari            6.0    57
# 3        4.0      Sergio Pérez       815        Red Bull            9.0    57
# 4        5.0    George Russell       847        Mercedes           13.1    57
# 5        6.0    Lewis Hamilton         1        Mercedes           13.1    57
# 6        7.0   Valtteri Bottas        77      Alfa Romeo           51.0    57
# 7        8.0      Esteban Ocon       839  Alpine F1 Team           21.4    57
# 8        9.0   Alexander Albon        23        Williams            3.0    57
# 9       10.0      Lance Stroll       840    Aston Martin           11.7    57
# 10      11.0   Fernando Alonso         4  Alpine F1 Team           21.4    57
# 11      12.0      Yuki Tsunoda       852      AlphaTauri           21.3    57
# 12      13.0  Daniel Ricciardo       817         McLaren            1.0    57
# 13      14.0   Nicholas Latifi         5        Williams            3.0    57
# 14      15.0   Mick Schumacher        47    Haas F1 Team           21.0    57
# 15      16.0   Kevin Magnussen        76    Haas F1 Team           21.0    56
# 16      17.0  Sebastian Vettel        20    Aston Martin           11.7    54
# 17       NaN      Pierre Gasly       842      AlphaTauri           21.3    45
# 18       NaN      Lando Norris       846         McLaren            1.0    39
# 19       NaN       Guanyu Zhou        24      Alfa Romeo           51.0     6
#
#            time  points  grid
# 0   1:34:24.258      26     3
# 1         3.786      18     1
# 2         8.229      15     2
# 3        10.638      12     4
# 4        18.582      10    12
# 5        21.368       8     6
# 6        25.073       6     5
# 7        28.386       4    20
# 8        32.365       2    18
# 9        37.026       1    10
# 10       37.128       0    11
# 11       40.146       0     9
# 12       40.902       0    14
# 13       49.936       0    19
# 14    +1:13.305       0    15
# 15   Front wing       0    16
# 16    Collision       0    13
# 17   Suspension       0     7
# 18    Collision       0     8
# 19   Water leak       0    17

# %%
# X = Drivers ID, y = Final Position, Z = Constructors ID, H = Grid

X = dataset.iloc[:-3,2:-6].values
y = dataset.iloc[:-3,:-8].values
Z = dataset.iloc[:-3,4:-4].values
H = dataset.iloc[:-3,8:].values

# %%
# Machine Learning  Regression Grid VS Final Position

from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(H, y)
# Out:
# LinearRegression()

# %%
# Miami GP Driver Position

plt.figure(figsize=(15,10))
plt.grid(color='green', linestyle='--', linewidth=0.5)
plt.scatter(X, y, color = 'blue')
plt.title('Miami GP Driver Position')
plt.xlabel('Driver ID')
plt.ylabel('Position')
# Out:
# Text(0, 0.5, 'Position')

# %%
# Miami GP Constructor Position 

plt.figure(figsize=(15,10))
plt.grid(color='green', linestyle='--', linewidth=0.5)
plt.scatter(Z, y, color = 'blue')
plt.title('Miami GP Constructor Position')
plt.xlabel('Constructor ID')
plt.ylabel('Position')
# Out:
# Text(0, 0.5, 'Position')

# %%
# Miami GP Driver Points

f, ax = plt.subplots(figsize=(15,10))
sns.barplot(x='points', y='driver', data=dataset)
plt.title('Miami GP Driver Points')
plt.xlabel('GP Points')
plt.ylabel('Drivers')
# Out:
# Text(0, 0.5, 'Drivers')

# %%
# Miami GP Constructor Points

f, ax = plt.subplots(figsize=(15,10))
sns.barplot(x='points', y='constructor', data=dataset)
plt.title('Miami GP Constructor Points')
plt.xlabel('GP Points')
plt.ylabel('Constructors')
# Out:
# Text(0, 0.5, 'Constructors')

# %%
# Miami GP Grid VS Final Position

plt.figure(figsize=(15,10))
plt.grid(color='green', linestyle='--', linewidth=0.5)
plt.scatter(H, y, color = 'red')
plt.plot(H, regressor.predict(H), color='blue')
plt.title('Grid VS Finish')
plt.xlabel('Start Position')
plt.ylabel('Finish')
# Out:
# Text(0, 0.5, 'Finish')
