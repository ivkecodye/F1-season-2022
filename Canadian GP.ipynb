# %%
# Libraries and Dataset

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
# %matplotlib inline
dataset = pd.read_csv('Canadian GP.csv')
dataset.head(20)
# Out:
#     position            driver  driver id     constructor  constructor id  \
# 0        1.0    Max Verstappen         50        Red Bull             9.0
# 1        2.0      Carlos Sainz        832         Ferrari             6.0
# 2        3.0    Lewis Hamilton          1        Mercedes            13.1
# 3        4.0    George Russell        847        Mercedes            13.1
# 4        5.0   Charles Leclerc        844         Ferrari             6.0
# 5        6.0      Esteban Ocon        839  Alpine F1 Team            21.4
# 6        7.0   Valtteri Bottas         77      Alfa Romeo            51.0
# 7        8.0       Guanyu Zhou         24      Alfa Romeo            51.0
# 8        9.0   Fernando Alonso          4  Alpine F1 Team            21.4
# 9       10.0      Lance Stroll        840    Aston Martin            11.7
# 10      11.0  Daniel Ricciardo        817         McLaren             1.0
# 11      12.0  Sebastian Vettel         20    Aston Martin            11.7
# 12      13.0   Alexander Albon         23        Williams             3.0
# 13      14.0      Pierre Gasly        842      AlphaTauri            21.3
# 14      15.0      Lando Norris        846         McLaren             1.0
# 15      16.0   Nicholas Latifi          5        Williams             3.0
# 16      17.0   Kevin Magnussen         76    Haas F1 Team            21.0
# 17       NaN      Yuki Tsunoda        852      AlphaTauri            21.3
# 18       NaN   Mick Schumacher         47    Haas F1 Team            21.0
# 19       NaN      Sergio Pérez        815        Red Bull             9.0
#
#     laps         time  points  grid
# 0     70  1:36:21.757      25     1
# 1     70        0.993      19     3
# 2     70        7.006      15     4
# 3     70       12.313      12     8
# 4     70       15.168      10    15
# 5     70       23.890       8     7
# 6     70       25.247       6    11
# 7     70       26.952       4    10
# 8     70       29.945       2     2
# 9     70       38.222       1    18
# 10    70       43.047       0     9
# 11    70       44.245       0    17
# 12    70       44.893       0    12
# 13    70       45.183       0    16
# 14    70       52.145       0    14
# 15    70       59.978       0    19
# 16    70    +1:08.180       0     5
# 17    47     Accident       0    20
# 18    18       Engine       0     6
# 19     7      Gearbox       0    13

# %%
# X = Drivers ID, y = Final Position, Z = Constructors ID, H = Grid

X = dataset.iloc[:-3,2:-6].values
y = dataset.iloc[:-3,:-8].values 
Z = dataset.iloc[:-3,4:-4].values
H = dataset.iloc[:-3,8:].values

# %%
# Machine Learning Regression Grid VS Final Position 

from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(H, y)
# Out:
# LinearRegression()

# %%
# Canadian GP Driver Position

plt.figure(figsize=(15,10))
plt.grid(color='green', linestyle='--', linewidth='0.5')
plt.scatter(X, y, color = 'blue')
plt.title('Canadian GP Driver Position')
plt.xlabel('Driver ID')
plt.ylabel('Position')
# Out:
# Text(0, 0.5, 'Position')

# %%
# Canadian GP Constructor Position

plt.figure(figsize=(15,10))
plt.grid(color='green', linestyle='--', linewidth='0.5')
plt.scatter(Z, y, color = 'blue')
plt.title('Canadian GP Constructor Position')
plt.xlabel('Constructor ID')
plt.ylabel('Position')
# Out:
# Text(0, 0.5, 'Position')

# %%
# Canadian GP Driver Points

f, ax = plt.subplots(figsize=(15, 10))
sns.barplot(x='points', y='driver', data=dataset)
plt.title('Canadian GP Driver Points')
plt.xlabel('GP Points')
plt.ylabel('Drivers')
# Out:
# Text(0, 0.5, 'Drivers')

# %%
# Canadian GP Constructor Points

f, ax = plt.subplots(figsize=(15, 10))
sns.barplot(x='points', y='constructor', data=dataset)
plt.title('Canadian GP Constructor Points')
plt.xlabel('GP Points')
plt.ylabel('Constructors')
# Out:
# Text(0, 0.5, 'Constructors')

# %%
# Canadian GP Grid VS Final Position

plt.figure(figsize=(15, 10))
plt.grid(color='green', linestyle='--', linewidth=0.5)
plt.scatter(H, y, color = 'red')
plt.plot(H, regressor.predict(H), color = 'blue')
plt.title('Grid VS Finish')
plt.xlabel('Start Position')
plt.ylabel('Finish')
# Out:
# Text(0, 0.5, 'Finish')
