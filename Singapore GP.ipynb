# %%
# Libraries and Dataset

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
# %matplotlib inline
dataset = pd.read_csv('Singapore GP.csv')
dataset.head(20)
# Out:
#     position            driver  driver id     constructor  constructor id  \
# 0        1.0      Sergio Pérez        815        Red Bull             9.0
# 1        2.0   Charles Leclerc        844         Ferrari             6.0
# 2        3.0      Carlos Sainz        832         Ferrari             6.0
# 3        4.0      Lando Norris        846         McLaren             1.0
# 4        5.0  Daniel Ricciardo        817         McLaren             1.0
# 5        6.0      Lance Stroll        840    Aston Martin            11.7
# 6        7.0    Max Verstappen         50        Red Bull             9.0
# 7        8.0  Sebastian Vettel         20    Aston Martin            11.7
# 8        9.0    Lewis Hamilton          1        Mercedes            13.1
# 9       10.0      Pierre Gasly        842      AlphaTauri            21.3
# 10      11.0   Valtteri Bottas         77      Alfa Romeo            51.0
# 11      12.0   Kevin Magnussen         76    Haas F1 Team            21.0
# 12      13.0   Mick Schumacher         47    Haas F1 Team            21.0
# 13      14.0    George Russell        847        Mercedes            13.1
# 14       NaN      Yuki Tsunoda        852      AlphaTauri            21.3
# 15       NaN      Esteban Ocon        839  Alpine F1 Team            21.4
# 16       NaN   Alexander Albon         23        Williams             3.0
# 17       NaN   Fernando Alonso          4  Alpine F1 Team            21.4
# 18       NaN   Nicholas Latifi          5        Williams             3.0
# 19       NaN       Guanyu Zhou         24      Alfa Romeo            51.0
#
#     laps              time  points  grid
# 0     59       2:02:20.238      25     2
# 1     59             2.595      18     1
# 2     59            10.305      15     4
# 3     59            21.133      12     6
# 4     59            53.282      10    17
# 5     59            56.330       8    12
# 6     59            58.825       6     8
# 7     59         +1:00.032       4    14
# 8     59         +1:01.515       2     3
# 9     59         +1:09.576       1     7
# 10    59         +1:28.844       0    16
# 11    59         +1:32.610       0     9
# 12    58            +1 Lap       0    13
# 13    57           +2 Laps       0    11
# 14    34          Accident       0    10
# 15    26            Engine       0    18
# 16    25  Collision damage       0    19
# 17    20            Engine       0     5
# 18     7  Collision damage       0    20
# 19     6         Collision       0    15

# %%
# X = Drivers ID, y = Final Position, Z = Constructors ID, H = Grid

X = dataset.iloc[:-6,2:-6].values
y = dataset.iloc[:-6,:-8].values 
Z = dataset.iloc[:-6,4:-4].values
H = dataset.iloc[:-6,8:].values

# %%
# Machine Learning Regression Grid VS Final Position 

from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(H, y)
# Out:
# LinearRegression()

# %%
# Singapore GP Driver Position

plt.figure(figsize=(15,10))
plt.grid(color='green', linestyle='--', linewidth='0.5')
plt.scatter(X, y, color = 'blue')
plt.title('Singapore GP Driver Position')
plt.xlabel('Driver ID')
plt.ylabel('Position')
# Out:
# Text(0, 0.5, 'Position')

# %%
# Singapore GP Constructor Position

plt.figure(figsize=(15,10))
plt.grid(color='green', linestyle='--', linewidth='0.5')
plt.scatter(Z, y, color = 'blue')
plt.title('Singapore GP Constructor Position')
plt.xlabel('Constructor ID')
plt.ylabel('Position')
# Out:
# Text(0, 0.5, 'Position')

# %%
# Singapore GP Driver Points

f, ax = plt.subplots(figsize=(15, 10))
sns.barplot(x='points', y='driver', data=dataset)
plt.title('Singapore GP Driver Points')
plt.xlabel('GP Points')
plt.ylabel('Drivers')
# Out:
# Text(0, 0.5, 'Drivers')

# %%
# Singapore GP Constructor Points

f, ax = plt.subplots(figsize=(15, 10))
sns.barplot(x='points', y='constructor', data=dataset)
plt.title('Singapore GP Constructor Points')
plt.xlabel('GP Points')
plt.ylabel('Constructors')
# Out:
# Text(0, 0.5, 'Constructors')

# %%
# Singapore GP Grid VS Final Position

plt.figure(figsize=(15, 10))
plt.grid(color='green', linestyle='--', linewidth=0.5)
plt.scatter(H, y, color = 'red')
plt.plot(H, regressor.predict(H), color = 'blue')
plt.title('Grid VS Finish')
plt.xlabel('Start Position')
plt.ylabel('Finish')
# Out:
# Text(0, 0.5, 'Finish')
