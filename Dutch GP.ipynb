# %%
# Libraries and Dataset

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
# %matplotlib inline
dataset = pd.read_csv('Dutch GP.csv')
dataset.head(20)
# Out:
#     position            driver  driver id     constructor  constructor id  \
# 0        1.0    Max Verstappen         50        Red Bull             9.0
# 1        2.0    George Russell        847        Mercedes            13.1
# 2        3.0   Charles Leclerc        844         Ferrari             6.0
# 3        4.0    Lewis Hamilton          1        Mercedes            13.1
# 4        5.0      Sergio Pérez        815        Red Bull             9.0
# 5        6.0   Fernando Alonso          4  Alpine F1 Team            21.4
# 6        7.0      Lando Norris        846         McLaren             1.0
# 7        8.0      Carlos Sainz        832         Ferrari             6.0
# 8        9.0      Esteban Ocon        839  Alpine F1 Team            21.4
# 9       10.0      Lance Stroll        840    Aston Martin            11.7
# 10      11.0      Pierre Gasly        842      AlphaTauri            21.3
# 11      12.0   Alexander Albon         23        Williams             3.0
# 12      13.0   Mick Schumacher         47    Haas F1 Team            21.0
# 13      14.0  Sebastian Vettel         20    Aston Martin            11.7
# 14      15.0   Kevin Magnussen         76    Haas F1 Team            21.0
# 15      16.0       Guanyu Zhou         24      Alfa Romeo            51.0
# 16      17.0  Daniel Ricciardo        817         McLaren             1.0
# 17      18.0   Nicholas Latifi          5        Williams             3.0
# 18       NaN   Valtteri Bottas         77      Alfa Romeo            51.0
# 19       NaN      Yuki Tsunoda        852      AlphaTauri            21.3
#
#     laps          time  points  grid
# 0     72   1:36:42.773      26     1
# 1     72         4.071      18     6
# 2     72        10.929      15     2
# 3     72        13.016      12     4
# 4     72        18.168      10     5
# 5     72        18.754       8    13
# 6     72        19.306       6     7
# 7     72        20.916       4     3
# 8     72        21.117       2    12
# 9     72        22.459       1    10
# 10    72        27.009       0    11
# 11    72        30.390       0    15
# 12    72        32.995       0     8
# 13    72        36.007       0    19
# 14    72        36.869       0    18
# 15    72        37.320       0    14
# 16    72        37.764       0    17
# 17    71        +1 Lap       0    20
# 18    53        Engine       0    16
# 19    43  Differential       0     9

# %%
# X = Drivers ID, y = Final Position, Z = Constructors ID, H = Grid

X = dataset.iloc[:-2,2:-6].values
y = dataset.iloc[:-2,:-8].values 
Z = dataset.iloc[:-2,4:-4].values
H = dataset.iloc[:-2,8:].values

# %%
# Machine Learning Regression Grid VS Final Position 

from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(H, y)
# Out:
# LinearRegression()

# %%
# Dutch GP Driver Position

plt.figure(figsize=(15,10))
plt.grid(color='green', linestyle='--', linewidth='0.5')
plt.scatter(X, y, color = 'blue')
plt.title('Dutch GP Driver Position')
plt.xlabel('Driver ID')
plt.ylabel('Position')
# Out:
# Text(0, 0.5, 'Position')

# %%
# Dutch GP Constructor Position

plt.figure(figsize=(15,10))
plt.grid(color='green', linestyle='--', linewidth='0.5')
plt.scatter(Z, y, color = 'blue')
plt.title('Dutch GP Constructor Position')
plt.xlabel('Constructor ID')
plt.ylabel('Position')
# Out:
# Text(0, 0.5, 'Position')

# %%
# Dutch GP Driver Points

f, ax = plt.subplots(figsize=(15, 10))
sns.barplot(x='points', y='driver', data=dataset)
plt.title('Dutch GP Driver Points')
plt.xlabel('GP Points')
plt.ylabel('Drivers')
# Out:
# Text(0, 0.5, 'Drivers')

# %%
# Dutch GP Constructor Points

f, ax = plt.subplots(figsize=(15, 10))
sns.barplot(x='points', y='constructor', data=dataset)
plt.title('Dutch GP Constructor Points')
plt.xlabel('GP Points')
plt.ylabel('Constructors')
# Out:
# Text(0, 0.5, 'Constructors')

# %%
# Dutch GP Grid VS Final Position

plt.figure(figsize=(15, 10))
plt.grid(color='green', linestyle='--', linewidth=0.5)
plt.scatter(H, y, color = 'red')
plt.plot(H, regressor.predict(H), color = 'blue')
plt.title('Grid VS Finish')
plt.xlabel('Start Position')
plt.ylabel('Finish')
# Out:
# Text(0, 0.5, 'Finish')
