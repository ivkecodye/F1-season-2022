# %%
# Libraries and Dataset

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
# %matplotlib inline
dataset = pd.read_csv('US GP.csv')
dataset.head(20)
# Out:
#     position            driver  driver id     constructor  constructor id  \
# 0        1.0    Max Verstappen         50        Red Bull             9.0
# 1        2.0    Lewis Hamilton          1        Mercedes            13.1
# 2        3.0   Charles Leclerc        844         Ferrari             6.0
# 3        4.0      Sergio Pérez        815        Red Bull             9.0
# 4        5.0    George Russell        847        Mercedes            13.1
# 5        6.0      Lando Norris        846         McLaren             1.0
# 6        7.0   Fernando Alonso          4  Alpine F1 Team            21.4
# 7        8.0  Sebastian Vettel         20    Aston Martin            11.7
# 8        9.0   Kevin Magnussen         76    Haas F1 Team            21.0
# 9       10.0      Yuki Tsunoda        852      AlphaTauri            21.3
# 10      11.0      Esteban Ocon        839  Alpine F1 Team            21.4
# 11      12.0       Guanyu Zhou         24      Alfa Romeo            51.0
# 12      13.0   Alexander Albon         23        Williams             3.0
# 13      14.0      Pierre Gasly        842      AlphaTauri            21.3
# 14      15.0   Mick Schumacher         47    Haas F1 Team            21.0
# 15      16.0  Daniel Ricciardo        817         McLaren             1.0
# 16      17.0   Nicholas Latifi          5        Williams             3.0
# 17       NaN      Lance Stroll        840    Aston Martin            11.7
# 18       NaN   Valtteri Bottas         77      Alfa Romeo            51.0
# 19       NaN      Carlos Sainz        832         Ferrari             6.0
#
#     laps              time  points  grid
# 0     56       1:42:11.687      25     3
# 1     56             5.023      18     5
# 2     56             7.501      15     2
# 3     56             8.293      12     4
# 4     56            44.815      11     6
# 5     56            53.785       8     8
# 6     56            55.078       6     9
# 7     56         +1:05.354       4    12
# 8     56         +1:05.834       2    16
# 9     56         +1:10.919       1    15
# 10    56         +1:12.875       0    18
# 11    56         +1:16.164       0    14
# 12    56         +1:20.057       0    11
# 13    56         +1:21.763       0    13
# 14    56         +1:24.490       0    19
# 15    56         +1:30.487       0    17
# 16    56         +1:43.588       0    20
# 17    21         Collision       0     7
# 18    16          Spun off       0    10
# 19     1  Collision damage       0     1

# %%
# X = Drivers ID, y = Final Position, Z = Constructors ID, H = Grid

X = dataset.iloc[:-3,2:-6].values
y = dataset.iloc[:-3,:-8].values 
Z = dataset.iloc[:-3,4:-4].values
H = dataset.iloc[:-3,8:].values

# %%
# Machine Learning Regression Grid VS Final Position 

from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(H, y)
# Out:
# LinearRegression()

# %%
# US GP Driver Position

plt.figure(figsize=(15,10))
plt.grid(color='green', linestyle='--', linewidth='0.5')
plt.scatter(X, y, color = 'blue')
plt.title('US GP Driver Position')
plt.xlabel('Driver ID')
plt.ylabel('Position')
# Out:
# Text(0, 0.5, 'Position')

# %%
# US GP Constructor Position

plt.figure(figsize=(15,10))
plt.grid(color='green', linestyle='--', linewidth='0.5')
plt.scatter(Z, y, color = 'blue')
plt.title('US GP Constructor Position')
plt.xlabel('Constructor ID')
plt.ylabel('Position')
# Out:
# Text(0, 0.5, 'Position')

# %%
# US GP Driver Points

f, ax = plt.subplots(figsize=(15, 10))
sns.barplot(x='points', y='driver', data=dataset)
plt.title('US GP Driver Points')
plt.xlabel('GP Points')
plt.ylabel('Drivers')
# Out:
# Text(0, 0.5, 'Drivers')

# %%
# US GP Constructor Points

f, ax = plt.subplots(figsize=(15, 10))
sns.barplot(x='points', y='constructor', data=dataset)
plt.title('US GP Constructor Points')
plt.xlabel('GP Points')
plt.ylabel('Constructors')
# Out:
# Text(0, 0.5, 'Constructors')

# %%
# US GP Grid VS Final Position

plt.figure(figsize=(15, 10))
plt.grid(color='green', linestyle='--', linewidth=0.5)
plt.scatter(H, y, color = 'red')
plt.plot(H, regressor.predict(H), color = 'blue')
plt.title('Grid VS Finish')
plt.xlabel('Start Position')
plt.ylabel('Finish')
# Out:
# Text(0, 0.5, 'Finish')
