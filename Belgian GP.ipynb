# %%
# Libraries and Dataset

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
# %matplotlib inline
dataset = pd.read_csv('Belgian GP.csv')
dataset.head(20)
# Out:
#     position            driver  driver id     constructor  constructor id  \
# 0        1.0    Max Verstappen         50        Red Bull             9.0
# 1        2.0      Sergio Pérez        815        Red Bull             9.0
# 2        3.0      Carlos Sainz        832         Ferrari             6.0
# 3        4.0    George Russell        847        Mercedes            13.1
# 4        5.0   Fernando Alonso          4  Alpine F1 Team            21.4
# 5        6.0   Charles Leclerc        844         Ferrari             6.0
# 6        7.0      Esteban Ocon        839  Alpine F1 Team            21.4
# 7        8.0  Sebastian Vettel         20    Aston Martin            11.7
# 8        9.0      Pierre Gasly        842      AlphaTauri            21.3
# 9       10.0   Alexander Albon         23        Williams             3.0
# 10      11.0      Lance Stroll        840    Aston Martin            11.7
# 11      12.0      Lando Norris        846         McLaren             1.0
# 12      13.0      Yuki Tsunoda        852      AlphaTauri            21.3
# 13      14.0       Guanyu Zhou         24      Alfa Romeo            51.0
# 14      15.0  Daniel Ricciardo        817         McLaren             1.0
# 15      16.0   Kevin Magnussen         76    Haas F1 Team            21.0
# 16      17.0   Mick Schumacher         47    Haas F1 Team            21.0
# 17      18.0   Nicholas Latifi          5        Williams             3.0
# 18       NaN   Valtteri Bottas         77      Alfa Romeo            51.0
# 19       NaN    Lewis Hamilton          1        Mercedes            13.1
#
#     laps              time  points  grid
# 0     44       1:25:52.894      26     1
# 1     44            17.841      18     3
# 2     44            26.886      15     2
# 3     44            29.140      12     8
# 4     44         +1:13.256      10     6
# 5     44         +1:14.936       8     4
# 6     44         +1:15.640       6     5
# 7     44         +1:18.107       4    16
# 8     44         +1:32.181       2    12
# 9     44         +1:41.900       1     9
# 10    44         +1:43.078       0    14
# 11    44         +1:44.739       0    10
# 12    44         +1:45.217       0    19
# 13    44         +1:46.252       0    13
# 14    44         +1:47.163       0    11
# 15    43            +1 Lap       0    18
# 16    43            +1 Lap       0    15
# 17    43            +1 Lap       0    17
# 18     1          Accident       0    20
# 19     0  Collision damage       0     7

# %%
# X = Drivers ID, y = Final Position, Z = Constructors ID, H = Grid

X = dataset.iloc[:-2,2:-6].values
y = dataset.iloc[:-2,:-8].values 
Z = dataset.iloc[:-2,4:-4].values
H = dataset.iloc[:-2,8:].values

# %%
# Machine Learning Regression Grid VS Final Position 

from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(H, y)
# Out:
# LinearRegression()

# %%
# Belgian GP Driver Position

plt.figure(figsize=(15,10))
plt.grid(color='green', linestyle='--', linewidth='0.5')
plt.scatter(X, y, color = 'blue')
plt.title('Belgian GP Driver Position')
plt.xlabel('Driver ID')
plt.ylabel('Position')
# Out:
# Text(0, 0.5, 'Position')

# %%
# Belgian GP Constructor Position

plt.figure(figsize=(15,10))
plt.grid(color='green', linestyle='--', linewidth='0.5')
plt.scatter(Z, y, color = 'blue')
plt.title('Belgian GP Constructor Position')
plt.xlabel('Constructor ID')
plt.ylabel('Position')
# Out:
# Text(0, 0.5, 'Position')

# %%
# Belgian GP Driver Points

f, ax = plt.subplots(figsize=(15, 10))
sns.barplot(x='points', y='driver', data=dataset)
plt.title('Belgian GP Driver Points')
plt.xlabel('GP Points')
plt.ylabel('Drivers')
# Out:
# Text(0, 0.5, 'Drivers')

# %%
# Belgian GP Constructor Points

f, ax = plt.subplots(figsize=(15, 10))
sns.barplot(x='points', y='constructor', data=dataset)
plt.title('Belgian GP Constructor Points')
plt.xlabel('GP Points')
plt.ylabel('Constructors')
# Out:
# Text(0, 0.5, 'Constructors')

# %%
# Belgian GP Grid VS Final Position

plt.figure(figsize=(15, 10))
plt.grid(color='green', linestyle='--', linewidth=0.5)
plt.scatter(H, y, color = 'red')
plt.plot(H, regressor.predict(H), color = 'blue')
plt.title('Grid VS Finish')
plt.xlabel('Start Position')
plt.ylabel('Finish')
# Out:
# Text(0, 0.5, 'Finish')
