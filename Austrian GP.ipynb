# %%
# Libraries and Dataset

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
# %matplotlib inline
dataset = pd.read_csv('Austrian GP.csv')
dataset.head(20)
# Out:
#     position            driver  driver id     constructor  constructor id  \
# 0        1.0   Charles Leclerc        832         Ferrari             6.0
# 1        2.0    Max Verstappen         50        Red Bull             9.0
# 2        3.0    Lewis Hamilton          1        Mercedes            13.1
# 3        4.0    George Russell        847        Mercedes            13.1
# 4        5.0      Esteban Ocon        839  Alpine F1 Team            21.4
# 5        6.0   Mick Schumacher         47    Haas F1 Team            21.0
# 6        7.0      Lando Norris        846         McLaren             1.0
# 7        8.0   Kevin Magnussen         76    Haas F1 Team            21.0
# 8        9.0  Daniel Ricciardo        817         McLaren             1.0
# 9       10.0   Fernando Alonso          4  Alpine F1 Team            21.4
# 10      11.0   Valtteri Bottas         77      Alfa Romeo            51.0
# 11      12.0   Alexander Albon         23        Williams             3.0
# 12      13.0      Lance Stroll        840    Aston Martin            11.7
# 13      14.0       Guanyu Zhou         24      Alfa Romeo            51.0
# 14      15.0      Pierre Gasly        842      AlphaTauri            21.3
# 15      16.0      Yuki Tsunoda        852      AlphaTauri            21.0
# 16      17.0  Sebastian Vettel         20    Aston Martin            11.7
# 17       NaN      Carlos Sainz        832         Ferrari             6.0
# 18       NaN   Nicholas Latifi          5        Williams             3.0
# 19       NaN      Sergio Pérez        815        Red Bull             9.0
#
#     laps              time  points  grid
# 0     71       1:24:24.312      25     2
# 1     71             1.532      19     1
# 2     71            41.217      15     9
# 3     71            58.972      12     4
# 4     71         +1:08.436      10     5
# 5     70            +1 Lap       8     7
# 6     70            +1 Lap       6    15
# 7     70            +1 Lap       4     6
# 8     70            +1 Lap       2    16
# 9     70            +1 Lap       1     8
# 10    70            +1 Lap       0    12
# 11    70            +1 Lap       0    11
# 12    70            +1 Lap       0    17
# 13    70            +1 Lap       0    18
# 14    70            +1 Lap       0    10
# 15    70            +1 Lap       0    14
# 16    70            +1 Lap       0    20
# 17    56        Power Unit       0     3
# 18    48         Undertray       0    19
# 19    24  Collision damage       0    13

# %%
# X = Drivers ID, y = Final Position, Z = Constructors ID, H = Grid

X = dataset.iloc[:-3,2:-6].values
y = dataset.iloc[:-3,:-8].values 
Z = dataset.iloc[:-3,4:-4].values
H = dataset.iloc[:-3,8:].values

# %%
# Machine Learning Regression Grid VS Final Position 

from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(H, y)
# Out:
# LinearRegression()

# %%
# Austrian GP Driver Position

plt.figure(figsize=(15,10))
plt.grid(color='green', linestyle='--', linewidth='0.5')
plt.scatter(X, y, color = 'blue')
plt.title('Austrian GP Driver Position')
plt.xlabel('Driver ID')
plt.ylabel('Position')
# Out:
# Text(0, 0.5, 'Position')

# %%
# Austrian GP Constructor Position

plt.figure(figsize=(15,10))
plt.grid(color='green', linestyle='--', linewidth='0.5')
plt.scatter(Z, y, color = 'blue')
plt.title('Austrian GP Constructor Position')
plt.xlabel('Constructor ID')
plt.ylabel('Position')
# Out:
# Text(0, 0.5, 'Position')

# %%
# Austrian GP Driver Points

f, ax = plt.subplots(figsize=(15, 10))
sns.barplot(x='points', y='driver', data=dataset)
plt.title('Austrian GP Driver Points')
plt.xlabel('GP Points')
plt.ylabel('Drivers')
# Out:
# Text(0, 0.5, 'Drivers')

# %%
# Austrian GP Constructor Points

f, ax = plt.subplots(figsize=(15, 10))
sns.barplot(x='points', y='constructor', data=dataset)
plt.title('Austrian GP Constructor Points')
plt.xlabel('GP Points')
plt.ylabel('Constructors')
# Out:
# Text(0, 0.5, 'Constructors')

# %%
# Austrian GP Grid VS Final Position

plt.figure(figsize=(15, 10))
plt.grid(color='green', linestyle='--', linewidth=0.5)
plt.scatter(H, y, color = 'red')
plt.plot(H, regressor.predict(H), color = 'blue')
plt.title('Grid VS Finish')
plt.xlabel('Start Position')
plt.ylabel('Finish')
# Out:
# Text(0, 0.5, 'Finish')
