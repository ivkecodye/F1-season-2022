# %%
# Libraries and Dataset

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
# %matplotlib inline
dataset = pd.read_csv('Brazilian GP.csv')
dataset.head(20)
# Out:
#     position            driver  driver id     constructor  constructor id  \
# 0        1.0    George Russell        847        Mercedes            13.1
# 1        2.0    Lewis Hamilton          1        Mercedes            13.1
# 2        3.0      Carlos Sainz        832         Ferrari             6.0
# 3        4.0   Charles Leclerc        844         Ferrari             6.0
# 4        5.0   Fernando Alonso          4  Alpine F1 Team            21.4
# 5        6.0    Max Verstappen         50        Red Bull             9.0
# 6        7.0      Sergio Pérez        815        Red Bull             9.0
# 7        8.0      Esteban Ocon        839  Alpine F1 Team            21.4
# 8        9.0   Valtteri Bottas         77      Alfa Romeo            51.0
# 9       10.0      Lance Stroll        840    Aston Martin            11.7
# 10      11.0  Sebastian Vettel         20    Aston Martin            11.7
# 11      12.0       Guanyu Zhou         24      Alfa Romeo            51.0
# 12      13.0   Mick Schumacher         47    Haas F1 Team            21.0
# 13      14.0      Pierre Gasly        842      AlphaTauri            21.3
# 14      15.0   Alexander Albon         23        Williams             3.0
# 15      16.0   Nicholas Latifi          5        Williams             3.0
# 16      17.0      Yuki Tsunoda        852      AlphaTauri            21.3
# 17       NaN      Lando Norris        846         McLaren             1.0
# 18       NaN   Kevin Magnussen         76    Haas F1 Team            21.0
# 19       NaN  Daniel Ricciardo        817         McLaren             1.0
#
#     laps         time  points  grid
# 0     71  1:38:34.044      26     3
# 1     71        1.529      18     8
# 2     71        4.051      15     5
# 3     71        8.441      12    10
# 4     71        9.561      10     7
# 5     71       10.056       8     2
# 6     71       14.080       6     9
# 7     71       18.690       4     6
# 8     71       22.552       2    18
# 9     71       23.552       1    15
# 10    71       26.183       0    13
# 11    71       29.325       0    17
# 12    71       29.899       0    20
# 13    71       31.867       0    12
# 14    71       36.016       0    11
# 15    71       37.038       0    16
# 16    70       +1 Lap       0    19
# 17    50      Gearbox       0     4
# 18     0    Collision       0     1
# 19     0    Collision       0    14

# %%
# X = Drivers ID, y = Final Position, Z = Constructors ID, H = Grid

X = dataset.iloc[:-3,2:-6].values
y = dataset.iloc[:-3,:-8].values 
Z = dataset.iloc[:-3,4:-4].values
H = dataset.iloc[:-3,8:].values

# %%
# Machine Learning Regression Grid VS Final Position 

from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(H, y)
# Out:
# LinearRegression()

# %%
# Brazilian GP Driver Position

plt.figure(figsize=(15,10))
plt.grid(color='green', linestyle='--', linewidth='0.5')
plt.scatter(X, y, color = 'blue')
plt.title('Brazilian GP Driver Position')
plt.xlabel('Driver ID')
plt.ylabel('Position')
# Out:
# Text(0, 0.5, 'Position')

# %%
# Brazilian GP Constructor Position

plt.figure(figsize=(15,10))
plt.grid(color='green', linestyle='--', linewidth='0.5')
plt.scatter(Z, y, color = 'blue')
plt.title('Brazilian GP Constructor Position')
plt.xlabel('Constructor ID')
plt.ylabel('Position')
# Out:
# Text(0, 0.5, 'Position')

# %%
# Brazilian GP Driver Points

f, ax = plt.subplots(figsize=(15, 10))
sns.barplot(x='points', y='driver', data=dataset)
plt.title('Brazilian GP Driver Points')
plt.xlabel('GP Points')
plt.ylabel('Drivers')
# Out:
# Text(0, 0.5, 'Drivers')

# %%
# Brazilian GP Constructor Points

f, ax = plt.subplots(figsize=(15, 10))
sns.barplot(x='points', y='constructor', data=dataset)
plt.title('Brazilian GP Constructor Points')
plt.xlabel('GP Points')
plt.ylabel('Constructors')
# Out:
# Text(0, 0.5, 'Constructors')

# %%
# Brazilian GP Grid VS Final Position

plt.figure(figsize=(15, 10))
plt.grid(color='green', linestyle='--', linewidth=0.5)
plt.scatter(H, y, color = 'red')
plt.plot(H, regressor.predict(H), color = 'blue')
plt.title('Grid VS Finish')
plt.xlabel('Start Position')
plt.ylabel('Finish')
# Out:
# Text(0, 0.5, 'Finish')
