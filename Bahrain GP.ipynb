# %%
#Libraries, Read Out Dataset

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
# %matplotlib inline
dataset = pd.read_csv('Bahrain GP.csv')
dataset.head(20)
# Out:
#     position      driver  driverId     constructor  constructorId  laps  \
# 0        1.0    Leclerc        844         Ferrari            6.0    57
# 1        2.0       Sainz       832         Ferrari            6.0    57
# 2        3.0    Hamilton         1        Mercedes           13.1    57
# 3        4.0     Russell       847        Mercedes           13.1    57
# 4        5.0   Magnussen        76    Haas F1 Team           21.0    57
# 5        6.0      Bottas        77      Alfa Romeo           51.0    57
# 6        7.0        Ocon       839  Alpine F1 Team           21.4    57
# 7        8.0     Tsunoda       852      AlphaTauri           21.3    57
# 8        9.0      Alonso         4  Alpine F1 Team           21.4    57
# 9       10.0        Zhou        24      Alfa Romeo           51.0    57
# 10      11.0  Schumacher        47    Haas F1 Team           21.0    57
# 11      12.0      Stroll       840    Aston Martin           11.7    57
# 12      13.0       Albon        23        Williams            3.0    57
# 13      14.0   Ricciardo       817         McLaren            1.0    57
# 14      15.0      Norris       846         McLaren            1.0    57
# 15      16.0      Latifi         5        Williams            3.0    57
# 16      17.0  Hülkenberg       807    Aston Martin           11.7    57
# 17      18.0       Pérez       815        Red Bull            9.0    56
# 18      19.0  Verstappen        50        Red Bull            9.0    54
# 19       NaN       Gasly       842      AlphaTauri           21.3    44
#
#              time  points  grid
# 0     1:37:33.584      26     1
# 1           5.598      18     3
# 2           9.675      15     5
# 3          11.211      12     9
# 4          14.754      10     7
# 5          16.119       8     6
# 6          19.423       6    11
# 7          20.386       4    16
# 8          22.390       2     8
# 9          23.064       1    15
# 10         32.574       0    12
# 11         45.873       0    19
# 12         53.932       0    14
# 13         54.975       0    18
# 14         56.335       0    13
# 15      +1:01.795       0    20
# 16      +1:03.829       0    17
# 17  Fuel pressure       0     4
# 18  Fuel pressure       0     2
# 19     Power Unit       0    10

# %%
# X = Drivers ID, y = Final Position, Z = Constructors ID, H = Grid

X = dataset.iloc[:-1, 2:-6].values
y = dataset.iloc[:-1, :-8].values
Z = dataset.iloc[:-1, 4:-4].values
H = dataset.iloc[:-1, 8:].values

# %%
# Machine Learning Regression Grid vs Final Position

from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(H, y)
# Out:
# LinearRegression()

# %%
# Bahrain GP Driver Position

plt.figure(figsize=(15,10))
plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)
plt.scatter(X, y, color = 'blue')
plt.title('Bahrain GP Driver Positions')
plt.xlabel('Driver ID')
plt.ylabel('Position')
# Out:
# Text(0, 0.5, 'Position')

# %%
# Bahrain GP Constructor Position

plt.figure(figsize=(15,10))
plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)
plt.scatter(Z, y, color = 'blue')
plt.title('Bahrain GP Constructor Positions')
plt.xlabel('Constructor ID')
plt.ylabel('Position')
# Out:
# Text(0, 0.5, 'Position')

# %%
# Bahrain GP Driver Points

f, ax = plt.subplots(figsize=(15,10))
sns.barplot(x='points', y='driver', data=dataset)
plt.title('Bahrain GP Driver Points')
plt.xlabel('GP Points')
plt.ylabel('Drivers')
# Out:
# Text(0, 0.5, 'Drivers')

# %%
# Bahrain GP Constructor Points

f, ax = plt.subplots(figsize=(15,10))
sns.barplot(x='points', y='constructor', data=dataset)
plt.title('Bahrain GP Constructor Points')
plt.xlabel('GP Points')
plt.ylabel('Constructors')
# Out:
# Text(0, 0.5, 'Constructors')

# %%
# Bahrain GP Grid VS Finish Points

plt.figure(figsize=(15,10))
plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)
plt.scatter(H, y, color = 'red')
plt.plot(H, regressor.predict(H), color = 'blue')
plt.title('Grid VS Finish')
plt.xlabel('Start Position')
plt.ylabel('Finish Position')
# Out:
# Text(0, 0.5, 'Finish Position')
